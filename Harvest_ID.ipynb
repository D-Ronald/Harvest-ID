# %% [markdown]
# <a href="https://colab.research.google.com/github/D-Ronald/Harvest-ID/blob/main/Harvest_ID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Arquivo de treinamento:

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

SIZE = 256
SIZE_IMAGE = (SIZE,SIZE)

# criando um classificador para as doenças com base nas pastas de treino
TRAINING_DIR = "/content/sample_data/doenças/Training"
training_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255)

train_generator = training_datagen.flow_from_directory(TRAINING_DIR,
                                                       target_size=SIZE_IMAGE,
                                                       class_mode='categorical')

# criando um validador para verificação da precisão das doenças
VALIDATION_DIR = "/content/sample_data/doenças/Testing"
Validation_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255)

validation_generator = Validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              target_size = SIZE_IMAGE,
                                                              class_mode='categorical')

#train_generator = train_generator/SIZE
#validation_generator = validation_generator/SIZE
# definindo a quantidade de filtros por camada
filters_layer_conv1 = 64
filters_layer_conv2 = 64
filters_layer_conv3 = 128
filters_layer_conv4 = 128
filters_layer_dense = 512
filters_layer_out = 2

# instanciando o modelo 
model = tf.keras.models.Sequential(# construindo as camadas convolucionais
                                   [layers.Conv2D(filters_layer_conv1, (3, 3), activation='relu', input_shape=(SIZE, SIZE, 3)),
                                    layers.MaxPooling2D(2, 2),
                                    layers.Conv2D(filters_layer_conv2, (3, 3), activation='relu', input_shape=(SIZE, SIZE, 3)),
                                    layers.MaxPooling2D(2, 2),
                                    layers.Conv2D(filters_layer_conv3, (3, 3), activation='relu', input_shape=(SIZE, SIZE, 3)),
                                    layers.MaxPooling2D(2, 2),
                                    layers.Conv2D(filters_layer_conv4, (3, 3), activation='relu', input_shape=(SIZE, SIZE, 3)),
                                    layers.MaxPooling2D(2, 2),
                                    #Definindo a porcentagens de individuos que serão eliminados após cada geração
                                    layers.Dropout(0.5),
                                    #compactação das camadas 
                                    layers.Flatten(),
                                    # construindo a camada densa de entrada
                                    layers.Dense(filters_layer_dense, activation='relu'),
                                    #Construindo a camada densa de saída com a quantidade de filtro correspondendo a quantidade de classes
                                    layers.Dense(filters_layer_out, activation="softmax")])
#imprime as configurações das camadas, os parametros de saída e a quantidade de parametros
model.summary()

#compila as camadas do modelo e faz a otimização
history = model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

#Divide os dados em um conjunto de treinamento e um conjunto de validação, e usa o conjunto de validação para medir o progresso durante o treino.
model.fit(train_generator, epochs=100, validation_data=validation_generator, verbose=1,validation_steps = 3)
#salva os dados do 
model.save('Dados.keras')
# Out:
# Found 4092 images belonging to 2 classes.
# Found 628 images belonging to 2 classes.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_44 (Conv2D)          (None, 253, 253, 64)      1792
#
#  max_pooling2d_44 (MaxPoolin  (None, 126, 126, 64)     0
#  g2D)
#
#  conv2d_45 (Conv2D)          (None, 124, 124, 64)      36928
#
#  max_pooling2d_45 (MaxPoolin  (None, 62, 62, 64)       0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 60, 60, 128)       73856
#
#  max_pooling2d_46 (MaxPoolin  (None, 30, 30, 128)      0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 28, 28, 128)       147584
#
#  max_pooling2d_47 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 14, 14, 128)       0
#
#  flatten_11 (Flatten)        (None, 25088)             0
#
#  dense_22 (Dense)            (None, 512)               12845568
#
#  dense_23 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 13,106,754
# Trainable params: 13,106,754
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 128/128 [==============================] - 28s 191ms/step - loss: 0.1711 - accuracy: 0.9335 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 2/100
# 128/128 [==============================] - 23s 182ms/step - loss: 0.0583 - accuracy: 0.9822 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 3/100
# 128/128 [==============================] - 23s 183ms/step - loss: 0.0390 - accuracy: 0.9866 - val_loss: 0.0822 - val_accuracy: 0.9792
# Epoch 4/100
# 128/128 [==============================] - 22s 175ms/step - loss: 0.0289 - accuracy: 0.9917 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 5/100
# 128/128 [==============================] - 23s 176ms/step - loss: 0.0949 - accuracy: 0.9726 - val_loss: 0.1279 - val_accuracy: 0.9792
# Epoch 6/100
# 128/128 [==============================] - 22s 174ms/step - loss: 0.0642 - accuracy: 0.9773 - val_loss: 0.0510 - val_accuracy: 0.9896
# Epoch 7/100
# 128/128 [==============================] - 22s 174ms/step - loss: 0.0258 - accuracy: 0.9907 - val_loss: 5.4783e-04 - val_accuracy: 1.0000
# Epoch 8/100
# 128/128 [==============================] - 22s 175ms/step - loss: 0.0147 - accuracy: 0.9936 - val_loss: 5.4583e-04 - val_accuracy: 1.0000
# Epoch 9/100
# 128/128 [==============================] - 22s 174ms/step - loss: 0.0027 - accuracy: 0.9988 - val_loss: 1.0730e-04 - val_accuracy: 1.0000
# Epoch 10/100
# 128/128 [==============================] - 23s 177ms/step - loss: 8.7523e-04 - accuracy: 1.0000 - val_loss: 2.4585e-06 - val_accuracy: 1.0000
# Epoch 11/100
# 128/128 [==============================] - 22s 174ms/step - loss: 0.0126 - accuracy: 0.9976 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 12/100
# 128/128 [==============================] - 22s 174ms/step - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.0788 - val_accuracy: 0.9688
# Epoch 13/100
# 128/128 [==============================] - 22s 174ms/step - loss: 0.0206 - accuracy: 0.9934 - val_loss: 0.0534 - val_accuracy: 0.9896
# Epoch 14/100
# 128/128 [==============================] - 22s 174ms/step - loss: 0.0176 - accuracy: 0.9934 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 15/100
# 128/128 [==============================] - 22s 173ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 16/100
# 128/128 [==============================] - 22s 171ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 5.2049e-04 - val_accuracy: 1.0000
# Epoch 17/100
# 128/128 [==============================] - 22s 173ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0089 - val_accuracy: 0.9896
# Epoch 18/100
# 128/128 [==============================] - 22s 171ms/step - loss: 6.6662e-04 - accuracy: 0.9998 - val_loss: 1.1891e-04 - val_accuracy: 1.0000
# Epoch 19/100
# 128/128 [==============================] - 22s 173ms/step - loss: 8.9712e-05 - accuracy: 1.0000 - val_loss: 1.0096e-05 - val_accuracy: 1.0000
# Epoch 20/100
# 128/128 [==============================] - 22s 174ms/step - loss: 1.4975e-04 - accuracy: 1.0000 - val_loss: 3.5311e-06 - val_accuracy: 1.0000
# Epoch 21/100
# 128/128 [==============================] - 23s 177ms/step - loss: 5.7637e-05 - accuracy: 1.0000 - val_loss: 6.4447e-07 - val_accuracy: 1.0000
# Epoch 22/100
# 128/128 [==============================] - 22s 174ms/step - loss: 1.9186e-05 - accuracy: 1.0000 - val_loss: 1.3383e-05 - val_accuracy: 1.0000
# Epoch 23/100
# 128/128 [==============================] - 22s 173ms/step - loss: 4.0278e-06 - accuracy: 1.0000 - val_loss: 3.9755e-06 - val_accuracy: 1.0000
# Epoch 24/100
# 128/128 [==============================] - 22s 172ms/step - loss: 3.9739e-06 - accuracy: 1.0000 - val_loss: 2.4835e-09 - val_accuracy: 1.0000
# Epoch 25/100
# 128/128 [==============================] - 22s 173ms/step - loss: 7.5455e-06 - accuracy: 1.0000 - val_loss: 1.3796e-06 - val_accuracy: 1.0000
# Epoch 26/100
# 128/128 [==============================] - 23s 178ms/step - loss: 3.9902e-06 - accuracy: 1.0000 - val_loss: 3.8751e-06 - val_accuracy: 1.0000
# Epoch 27/100
# 128/128 [==============================] - 22s 172ms/step - loss: 3.0034e-06 - accuracy: 1.0000 - val_loss: 8.6168e-06 - val_accuracy: 1.0000
# Epoch 28/100
# 128/128 [==============================] - 23s 177ms/step - loss: 5.5923e-06 - accuracy: 1.0000 - val_loss: 2.4554e-05 - val_accuracy: 1.0000
# Epoch 29/100
# 128/128 [==============================] - 22s 171ms/step - loss: 2.3397e-06 - accuracy: 1.0000 - val_loss: 9.9977e-06 - val_accuracy: 1.0000
# Epoch 30/100
# 128/128 [==============================] - 22s 173ms/step - loss: 5.7360e-06 - accuracy: 1.0000 - val_loss: 1.5980e-06 - val_accuracy: 1.0000
# Epoch 31/100
# 128/128 [==============================] - 22s 175ms/step - loss: 9.6978e-06 - accuracy: 1.0000 - val_loss: 5.2526e-07 - val_accuracy: 1.0000
# Epoch 32/100
# 128/128 [==============================] - 22s 173ms/step - loss: 3.3186e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 33/100
# 128/128 [==============================] - 22s 172ms/step - loss: 2.5865e-06 - accuracy: 1.0000 - val_loss: 3.5514e-07 - val_accuracy: 1.0000
# Epoch 34/100
# 128/128 [==============================] - 22s 173ms/step - loss: 2.3121e-06 - accuracy: 1.0000 - val_loss: 8.8039e-07 - val_accuracy: 1.0000
# Epoch 35/100
# 128/128 [==============================] - 22s 172ms/step - loss: 1.4699e-06 - accuracy: 1.0000 - val_loss: 1.1991e-05 - val_accuracy: 1.0000
# Epoch 36/100
# 128/128 [==============================] - 22s 174ms/step - loss: 1.4223e-06 - accuracy: 1.0000 - val_loss: 4.2273e-06 - val_accuracy: 1.0000
# Epoch 37/100
# 128/128 [==============================] - 23s 176ms/step - loss: 1.5592e-06 - accuracy: 1.0000 - val_loss: 6.6389e-06 - val_accuracy: 1.0000
# Epoch 38/100
# 128/128 [==============================] - 22s 172ms/step - loss: 1.1594e-06 - accuracy: 1.0000 - val_loss: 8.3190e-06 - val_accuracy: 1.0000
# Epoch 39/100
# 128/128 [==============================] - 22s 173ms/step - loss: 1.2493e-06 - accuracy: 1.0000 - val_loss: 3.5887e-07 - val_accuracy: 1.0000
# Epoch 40/100
# 128/128 [==============================] - 22s 175ms/step - loss: 4.5712e-07 - accuracy: 1.0000 - val_loss: 9.9341e-08 - val_accuracy: 1.0000
# Epoch 41/100
# 128/128 [==============================] - 22s 172ms/step - loss: 8.7372e-07 - accuracy: 1.0000 - val_loss: 6.2088e-09 - val_accuracy: 1.0000
# Epoch 42/100
# 128/128 [==============================] - 22s 173ms/step - loss: 1.0661e-06 - accuracy: 1.0000 - val_loss: 4.7949e-06 - val_accuracy: 1.0000
# Epoch 43/100
# 128/128 [==============================] - 22s 173ms/step - loss: 9.7994e-07 - accuracy: 1.0000 - val_loss: 3.6727e-06 - val_accuracy: 1.0000
# Epoch 44/100
# 128/128 [==============================] - 22s 173ms/step - loss: 9.6096e-07 - accuracy: 1.0000 - val_loss: 4.8050e-06 - val_accuracy: 1.0000
# Epoch 45/100
# 128/128 [==============================] - 22s 172ms/step - loss: 8.2471e-07 - accuracy: 1.0000 - val_loss: 4.9671e-09 - val_accuracy: 1.0000
# Epoch 46/100
# 128/128 [==============================] - 22s 174ms/step - loss: 1.4812e-06 - accuracy: 1.0000 - val_loss: 4.4446e-06 - val_accuracy: 1.0000
# Epoch 47/100
# 128/128 [==============================] - 22s 173ms/step - loss: 5.8268e-07 - accuracy: 1.0000 - val_loss: 7.2022e-08 - val_accuracy: 1.0000
# Epoch 48/100
# 128/128 [==============================] - 22s 172ms/step - loss: 3.3841e-07 - accuracy: 1.0000 - val_loss: 3.9036e-06 - val_accuracy: 1.0000
# Epoch 49/100
# 128/128 [==============================] - 22s 174ms/step - loss: 5.4567e-07 - accuracy: 1.0000 - val_loss: 3.7253e-09 - val_accuracy: 1.0000
# Epoch 50/100
# 128/128 [==============================] - 22s 173ms/step - loss: 4.4809e-07 - accuracy: 1.0000 - val_loss: 5.8858e-07 - val_accuracy: 1.0000
# Epoch 51/100
# 128/128 [==============================] - 22s 170ms/step - loss: 6.2351e-07 - accuracy: 1.0000 - val_loss: 9.1890e-08 - val_accuracy: 1.0000
# Epoch 52/100
# 128/128 [==============================] - 22s 175ms/step - loss: 2.7989e-07 - accuracy: 1.0000 - val_loss: 2.4835e-09 - val_accuracy: 1.0000
# Epoch 53/100
# 128/128 [==============================] - 22s 174ms/step - loss: 5.5538e-07 - accuracy: 1.0000 - val_loss: 1.9035e-06 - val_accuracy: 1.0000
# Epoch 54/100
# 128/128 [==============================] - 22s 175ms/step - loss: 2.4715e-07 - accuracy: 1.0000 - val_loss: 4.2220e-08 - val_accuracy: 1.0000
# Epoch 55/100
# 128/128 [==============================] - 22s 171ms/step - loss: 2.3588e-07 - accuracy: 1.0000 - val_loss: 2.3616e-06 - val_accuracy: 1.0000
# Epoch 56/100
# 128/128 [==============================] - 22s 172ms/step - loss: 6.9397e-07 - accuracy: 1.0000 - val_loss: 1.4279e-06 - val_accuracy: 1.0000
# Epoch 57/100
# 128/128 [==============================] - 22s 172ms/step - loss: 4.0704e-07 - accuracy: 1.0000 - val_loss: 1.8626e-07 - val_accuracy: 1.0000
# Epoch 58/100
# 128/128 [==============================] - 22s 173ms/step - loss: 4.0244e-07 - accuracy: 1.0000 - val_loss: 2.2848e-07 - val_accuracy: 1.0000
# Epoch 59/100
# 128/128 [==============================] - 22s 171ms/step - loss: 2.7759e-07 - accuracy: 1.0000 - val_loss: 4.4248e-06 - val_accuracy: 1.0000
# Epoch 60/100
# 128/128 [==============================] - 22s 174ms/step - loss: 3.3843e-07 - accuracy: 1.0000 - val_loss: 1.8463e-06 - val_accuracy: 1.0000
# Epoch 61/100
# 128/128 [==============================] - 22s 173ms/step - loss: 8.7629e-08 - accuracy: 1.0000 - val_loss: 2.0365e-07 - val_accuracy: 1.0000
# Epoch 62/100
# 128/128 [==============================] - 22s 172ms/step - loss: 2.2442e-07 - accuracy: 1.0000 - val_loss: 3.8495e-08 - val_accuracy: 1.0000
# Epoch 63/100
# 128/128 [==============================] - 22s 174ms/step - loss: 2.9849e-07 - accuracy: 1.0000 - val_loss: 1.2789e-06 - val_accuracy: 1.0000
# Epoch 64/100
# 128/128 [==============================] - 22s 174ms/step - loss: 9.8988e-08 - accuracy: 1.0000 - val_loss: 8.2078e-07 - val_accuracy: 1.0000
# Epoch 65/100
# 128/128 [==============================] - 23s 176ms/step - loss: 1.3613e-07 - accuracy: 1.0000 - val_loss: 8.6923e-09 - val_accuracy: 1.0000
# Epoch 66/100
# 128/128 [==============================] - 22s 175ms/step - loss: 9.2842e-08 - accuracy: 1.0000 - val_loss: 1.9371e-07 - val_accuracy: 1.0000
# Epoch 67/100
# 128/128 [==============================] - 22s 172ms/step - loss: 2.0220e-07 - accuracy: 1.0000 - val_loss: 2.4835e-08 - val_accuracy: 1.0000
# Epoch 68/100
# 128/128 [==============================] - 22s 175ms/step - loss: 7.7112e-08 - accuracy: 1.0000 - val_loss: 7.3137e-07 - val_accuracy: 1.0000
# Epoch 69/100
# 128/128 [==============================] - 23s 175ms/step - loss: 1.1093e-07 - accuracy: 1.0000 - val_loss: 1.4789e-06 - val_accuracy: 1.0000
# Epoch 70/100
# 128/128 [==============================] - 22s 171ms/step - loss: 7.4108e-07 - accuracy: 1.0000 - val_loss: 1.4901e-08 - val_accuracy: 1.0000
# Epoch 71/100
# 128/128 [==============================] - 22s 173ms/step - loss: 0.1266 - accuracy: 0.9817 - val_loss: 0.1430 - val_accuracy: 0.9583
# Epoch 72/100
# 128/128 [==============================] - 22s 171ms/step - loss: 0.0297 - accuracy: 0.9919 - val_loss: 0.0150 - val_accuracy: 0.9896
# Epoch 73/100
# 128/128 [==============================] - 22s 169ms/step - loss: 0.0112 - accuracy: 0.9956 - val_loss: 0.0088 - val_accuracy: 0.9896
# Epoch 74/100
# 128/128 [==============================] - 22s 169ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 75/100
# 128/128 [==============================] - 21s 167ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 76/100
# 128/128 [==============================] - 22s 170ms/step - loss: 0.0028 - accuracy: 0.9985 - val_loss: 1.4017e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 128/128 [==============================] - 22s 168ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 78/100
# 128/128 [==============================] - 22s 169ms/step - loss: 2.0396e-04 - accuracy: 1.0000 - val_loss: 1.0621e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 128/128 [==============================] - 22s 170ms/step - loss: 2.0670e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9896
# Epoch 80/100
# 128/128 [==============================] - 22s 168ms/step - loss: 2.2518e-04 - accuracy: 1.0000 - val_loss: 1.4243e-06 - val_accuracy: 1.0000
# Epoch 81/100
# 128/128 [==============================] - 22s 170ms/step - loss: 1.1775e-04 - accuracy: 1.0000 - val_loss: 3.8138e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 128/128 [==============================] - 22s 169ms/step - loss: 1.1109e-05 - accuracy: 1.0000 - val_loss: 3.9718e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 128/128 [==============================] - 22s 168ms/step - loss: 1.7368e-05 - accuracy: 1.0000 - val_loss: 3.9942e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 128/128 [==============================] - 22s 168ms/step - loss: 7.0117e-06 - accuracy: 1.0000 - val_loss: 6.5847e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 128/128 [==============================] - 22s 168ms/step - loss: 2.5093e-04 - accuracy: 1.0000 - val_loss: 3.0983e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 128/128 [==============================] - 22s 170ms/step - loss: 0.0225 - accuracy: 0.9927 - val_loss: 1.9826e-05 - val_accuracy: 1.0000
# Epoch 87/100
# 128/128 [==============================] - 22s 168ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 88/100
# 128/128 [==============================] - 22s 168ms/step - loss: 0.0122 - accuracy: 0.9973 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 89/100
# 128/128 [==============================] - 22s 170ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 90/100
# 128/128 [==============================] - 22s 167ms/step - loss: 1.3875e-04 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9896
# Epoch 91/100
# 128/128 [==============================] - 22s 168ms/step - loss: 1.8006e-05 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 92/100
# 128/128 [==============================] - 22s 169ms/step - loss: 1.0069e-05 - accuracy: 1.0000 - val_loss: 6.8296e-07 - val_accuracy: 1.0000
# Epoch 93/100
# 128/128 [==============================] - 22s 169ms/step - loss: 1.1075e-05 - accuracy: 1.0000 - val_loss: 1.7745e-05 - val_accuracy: 1.0000
# Epoch 94/100
# 128/128 [==============================] - 22s 167ms/step - loss: 4.6590e-06 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 95/100
# 128/128 [==============================] - 22s 170ms/step - loss: 5.2451e-06 - accuracy: 1.0000 - val_loss: 1.2790e-07 - val_accuracy: 1.0000
# Epoch 96/100
# 128/128 [==============================] - 22s 169ms/step - loss: 1.6289e-05 - accuracy: 1.0000 - val_loss: 5.8328e-06 - val_accuracy: 1.0000
# Epoch 97/100
# 128/128 [==============================] - 22s 167ms/step - loss: 1.7046e-05 - accuracy: 1.0000 - val_loss: 3.3528e-08 - val_accuracy: 1.0000
# Epoch 98/100
# 128/128 [==============================] - 22s 169ms/step - loss: 6.8132e-06 - accuracy: 1.0000 - val_loss: 6.2088e-09 - val_accuracy: 1.0000
# Epoch 99/100
# 128/128 [==============================] - 22s 168ms/step - loss: 2.3360e-06 - accuracy: 1.0000 - val_loss: 8.4892e-06 - val_accuracy: 1.0000
# Epoch 100/100
# 128/128 [==============================] - 22s 168ms/step - loss: 3.9260e-06 - accuracy: 1.0000 - val_loss: 2.0708e-05 - val_accuracy: 1.0000
